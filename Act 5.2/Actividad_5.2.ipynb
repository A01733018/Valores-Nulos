# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data = pd.read_excel('Gastos y costos 20-23.xlsx')
data
# Out:
#      CALOR Y CONTROL S.A DE C.V Unnamed: 1  \
# 0              DEDUCCIONES 2020        NaN
# 1                           NaN        NaN
# 2                           NaN        NaN
# 3                           NaN        NaN
# 4                         FECHA      FOLIO
# ...                         ...        ...
# 3342        2020-12-01 00:00:00     125834
# 3343        2020-12-01 00:00:00      37652
# 3344        2020-12-01 00:00:00        160
# 3345        2020-12-01 00:00:00     634875
# 3346        2020-12-01 00:00:00    1044477
#
#                                 Unnamed: 2    Unnamed: 3  \
# 0                                      NaN           NaN
# 1                                      NaN           NaN
# 2                                      NaN           NaN
# 3                                      NaN           NaN
# 4                                     UUID           RFC
# ...                                    ...           ...
# ...

# %%
#Eliminar primera fila o filas innecesarias
data= pd.read_excel('Gastos y costos 20-23.xlsx', skiprows=5)
data
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
#Realizamos una copia del dataframe
data1=data.copy()

# %%
#Identificar valores nulos por columna
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC              391
# IMPORTE          34
# IVA             268
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
data1["FOLIO"]= data1["FOLIO"].fillna(0) 
data1.head()

#Aqui busco dejar una marca numerica para saber que folios faltan ya que este es unico para las personas en todos los casos.
# Out:
#        FECHA                   FOLIO                                  UUID  \
# 0 2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1 2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2 2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3 2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4 2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
#
#             RFC                                          PROVEEDOR  \
# 0  ARE080115PBA                                ARSI RENTA SA DE CV
# 1  BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 2  BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 3  PSS120625C86  PROMOTORA DE SERVICIOS Y SOLUCIONES EMPRESARIA...
# 4  ENA7006081P0                   ELECTROTERMICA NACIONAL SA DE CV
#
#              TIPO GASTO GASTO  \
# 0            MAQUINARIA   NaN
# 1     COMISION BANCARIA   NaN
# ...

# %%
#Convertir DataFrame a CSV
data1.to_csv("Act5.2_FOLIO.csv")

# %%
#Sustituir valores nulos por un string en  concreto 
data1["GASTO"] =data1["GASTO"].fillna("NO EXISTE") 

#Esta columna contiene palabras por lo que para identificar los faltantes agregue la palabra "no existe"

# %%
#Convertir DataFrame a CSV
data1.to_csv("Act5.2_GASTO.csv")

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
data1["TC"]= data1["TC"].fillna(0) 
data1.head

#En su mayoria de esa columna estan escritos un 1 o una secuencia de numeros por lo que para identificar y eliminar los valores nulos agregue el numero 0.
# Out:
# <bound method NDFrame.head of           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
#Convertir DataFrame a CSV
data1.to_csv("Act5.2_TC.csv")

# %%
#Sustituir valores nulos con promedio o media
data1["IMPORTE"]=data1["IMPORTE"].fillna(round(data["IMPORTE"].mean(),1))

#Al ser resultados numericos creo lo más sensato es hacer el promedio de todos los resultados para que no afecten de una forma muy brusca la información.

# %%
#Convertir DataFrame a CSV
data1.to_csv("Act5.2_IMPORTE.csv")

# %%
#Sustituir valores nulos con mediana
data1["IVA"]=data1["IVA"].fillna(round(data["IVA"].median(),1))

#Todos los valores son muy variados por lo que no se puede saber un estimado, use la media ya que queria usar un nuevo metodo que no aleje tanto los resultados de la realidad.

# %%
#Convertir DataFrame a CSV
data1.to_csv("Act5.2_IVA.csv")

# %%
#Sustituir valores nulos por un string en  concreto 
data1["TIPO"] =data1["TIPO"].fillna("NO EXISTE") 

#Esta columna contiene palabras por lo que para identificar los faltantes agregue la palabra "no existe"

# %%
#Convertir DataFrame a CSV
data1.to_csv("Act5.2_TIPO.csv")

# %%
#Sustituir valores nulos por un string en  concreto 
data1["POLIZA"] =data1["POLIZA"].fillna("DATO FALTANTE") 

#Esta columna contiene palabras por lo que para identificar los faltantes agregue la palabra "no existe"

# %%
#Convertir DataFrame a CSV
data1.to_csv("Act5.2_POLIZA.csv")

# %%
#Identificar valores nulos por columna
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# GASTO          0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# Columna1       0
# dtype: int64
